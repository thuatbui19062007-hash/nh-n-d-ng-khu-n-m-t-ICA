# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
import numpy as np
import matplotlib.pyplot as plt


train_dir = '/content/drive/MyDrive/Ảnh Lớp IC'

img_width, img_height = 280, 280
batch_size = 32

train_datagen = ImageDataGenerator(
    rescale=1/255,
    shear_range=0.2,
    zoom_range=0.2,
    height_shift_range=0.2,
    width_shift_range=0.2, # Sửa tên biến từ img_width_shift_range thành width_shift_range
    horizontal_flip=True,
    fill_mode='nearest'
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 1606 images belonging to 34 classes.

# %%
from keras.layers import Input, Conv2D, MaxPool2D, MaxPooling2D, Dense, Flatten, Dropout

model = Sequential([
    Input(shape=(img_width, img_height, 3)),
    Conv2D(33, (3, 3), activation='relu'),
    MaxPool2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(34, activation='softmax')
])

# %%
model.compile(optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"])
model.summary()
epochs=30
history=model.fit(train_generator, epochs=epochs)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 278, 278, 33)   │           924 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 139, 139, 33)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 137, 137, 64)   │        19,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 68, 68, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 66, 66, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 33, 33, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 139392)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │    17,842,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 34)             │         4,386 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,940,542 (68.44 MB)
#  Trainable params: 17,940,542 (68.44 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 467s 9s/step - accuracy: 0.1376 - loss: 3.1082
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 394s 8s/step - accuracy: 0.3076 - loss: 2.4083
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 402s 8s/step - accuracy: 0.4278 - loss: 1.9136
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 448s 8s/step - accuracy: 0.5274 - loss: 1.7042
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 393s 8s/step - accuracy: 0.6090 - loss: 1.3930
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 406s 8s/step - accuracy: 0.6737 - loss: 1.0736
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 405s 8s/step - accuracy: 0.6961 - loss: 1.0741
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 395s 8s/step - accuracy: 0.7347 - loss: 0.9294
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 407s 8s/step - accuracy: 0.7503 - loss: 0.8578
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 401s 8s/step - accuracy: 0.7846 - loss: 0.7151
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 394s 8s/step - accuracy: 0.7964 - loss: 0.7135
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 403s 8s/step - accuracy: 0.8250 - loss: 0.6164
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 394s 8s/step - accuracy: 0.8207 - loss: 0.6016
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 406s 8s/step - accuracy: 0.8281 - loss: 0.5936
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 440s 8s/step - accuracy: 0.8362 - loss: 0.5597
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 395s 8s/step - accuracy: 0.8487 - loss: 0.5404
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 393s 8s/step - accuracy: 0.8730 - loss: 0.4817
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 393s 8s/step - accuracy: 0.8661 - loss: 0.4684
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 393s 8s/step - accuracy: 0.8667 - loss: 0.4272
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 409s 8s/step - accuracy: 0.8879 - loss: 0.4133
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 440s 8s/step - accuracy: 0.8848 - loss: 0.3981
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 393s 8s/step - accuracy: 0.8867 - loss: 0.4032
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 402s 8s/step - accuracy: 0.9029 - loss: 0.3196
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 401s 8s/step - accuracy: 0.8985 - loss: 0.3699
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 435s 8s/step - accuracy: 0.8966 - loss: 0.3680
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 392s 8s/step - accuracy: 0.9110 - loss: 0.2986
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 393s 8s/step - accuracy: 0.9010 - loss: 0.3439
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 393s 8s/step - accuracy: 0.9147 - loss: 0.3031
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 394s 8s/step - accuracy: 0.9209 - loss: 0.3499
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 393s 8s/step - accuracy: 0.9228 - loss: 0.2577

# %%
from keras.utils import load_img
import numpy as np
path="/content/drive/MyDrive/Ảnh Lớp IC/BÙI VÕ THUẬT/z7869354380992_f744acb22e2818b15bb685ae8853195e.jpg"
img=load_img(path,target_size=(280,280))
plt.imshow(img)
img=np.array(img)
img=img/255.0
img=img.reshape(1,280,280,3)
prediction=np.argmax(model.predict(img))
class_labels={v:k for k, v in train_generator.class_indices.items()}
person_name=class_labels[prediction]
print(f"Người tiên đoán:{person_name}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# Người tiên đoán:BÙI VÕ THUẬT
